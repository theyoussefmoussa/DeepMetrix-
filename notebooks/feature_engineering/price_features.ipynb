# %%
import polars as pr
import numpy as np

# %%
cols = ["item_store_id", "day_number", "sell_price", "sales"]
df = pr.read_parquet('/home/youssef/Projects/walmart-stores/data/processed/df_merged.parquet', columns=cols)
df.head(5)
