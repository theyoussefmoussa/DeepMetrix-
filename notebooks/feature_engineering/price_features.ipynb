# %%
import polars as pr
import numpy as np
import os 
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
BASE_PATH = os.environ.get("BASE_PATH")
cols = ["item_store_id", "day_number", "sell_price", "sales"]
df = pr.read_parquet(f'{BASE_PATH}/data/processed/df_merged.parquet', columns=cols)
df.head(5)
